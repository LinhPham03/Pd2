# %%
import pandas as pd

df = pd.read_csv(r'C:\\Users\\Admin\\Downloads\\OnlineRetail.csv',encoding= 'unicode_escape')
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
df.pivot_table('Quantity',index = 'InvoiceNo',columns = 'Country',aggfunc = 'mean')
# Out:
# Country    Australia  Austria  Bahrain  Belgium  Brazil  Canada  \
# InvoiceNo
# 536365           NaN      NaN      NaN      NaN     NaN     NaN
# 536366           NaN      NaN      NaN      NaN     NaN     NaN
# 536367           NaN      NaN      NaN      NaN     NaN     NaN
# 536368           NaN      NaN      NaN      NaN     NaN     NaN
# 536369           NaN      NaN      NaN      NaN     NaN     NaN
# ...              ...      ...      ...      ...     ...     ...
# C581484          NaN      NaN      NaN      NaN     NaN     NaN
# C581490          NaN      NaN      NaN      NaN     NaN     NaN
# C581499          NaN      NaN      NaN      NaN     NaN     NaN
# C581568          NaN      NaN      NaN      NaN     NaN     NaN
# C581569          NaN      NaN      NaN      NaN     NaN     NaN
#
# Country    Channel Islands  Cyprus  Czech Republic  Denmark  ...  RSA  \
# InvoiceNo                                                    ...
# ...

# %%
df.pivot_table('Quantity',index = 'CustomerID',columns = 'StockCode',aggfunc = 'max')
# Out:
# StockCode   10002  10080  10120  10123C  10124A  10124G  10125  10133  10135  \
# CustomerID
# 12346.0       NaN    NaN    NaN     NaN     NaN     NaN    NaN    NaN    NaN
# 12347.0       NaN    NaN    NaN     NaN     NaN     NaN    NaN    NaN    NaN
# 12348.0       NaN    NaN    NaN     NaN     NaN     NaN    NaN    NaN    NaN
# 12349.0       NaN    NaN    NaN     NaN     NaN     NaN    NaN    NaN    NaN
# 12350.0       NaN    NaN    NaN     NaN     NaN     NaN    NaN    NaN    NaN
# ...           ...    ...    ...     ...     ...     ...    ...    ...    ...
# 18280.0       NaN    NaN    NaN     NaN     NaN     NaN    NaN    NaN    NaN
# 18281.0       NaN    NaN    NaN     NaN     NaN     NaN    NaN    NaN    NaN
# 18282.0       NaN    NaN    NaN     NaN     NaN     NaN    NaN    NaN    NaN
# 18283.0       NaN    NaN    NaN     NaN     NaN     NaN    NaN    NaN    NaN
# 18287.0       NaN    NaN    NaN     NaN     NaN     NaN    NaN    NaN    NaN
#
# ...

# %%
df.pivot_table('Quantity',index = 'CustomerID',columns = 'StockCode',aggfunc = 'min')
# Out:
# StockCode   10002  10080  10120  10123C  10124A  10124G  10125  10133  10135  \
# CustomerID
# 12346.0       NaN    NaN    NaN     NaN     NaN     NaN    NaN    NaN    NaN
# 12347.0       NaN    NaN    NaN     NaN     NaN     NaN    NaN    NaN    NaN
# 12348.0       NaN    NaN    NaN     NaN     NaN     NaN    NaN    NaN    NaN
# 12349.0       NaN    NaN    NaN     NaN     NaN     NaN    NaN    NaN    NaN
# 12350.0       NaN    NaN    NaN     NaN     NaN     NaN    NaN    NaN    NaN
# ...           ...    ...    ...     ...     ...     ...    ...    ...    ...
# 18280.0       NaN    NaN    NaN     NaN     NaN     NaN    NaN    NaN    NaN
# 18281.0       NaN    NaN    NaN     NaN     NaN     NaN    NaN    NaN    NaN
# 18282.0       NaN    NaN    NaN     NaN     NaN     NaN    NaN    NaN    NaN
# 18283.0       NaN    NaN    NaN     NaN     NaN     NaN    NaN    NaN    NaN
# 18287.0       NaN    NaN    NaN     NaN     NaN     NaN    NaN    NaN    NaN
#
# ...

# %%
data1 = df.pivot_table('Quantity',index = 'StockCode',aggfunc = 'sum')
data1
# Out:
#               Quantity
# StockCode
# 10002             1037
# 10080              495
# 10120              193
# 10123C             -13
# 10123G             -38
# ...                ...
# gift_0001_20        20
# gift_0001_30        37
# gift_0001_40         3
# gift_0001_50         4
# m                    1
#
# [4070 rows x 1 columns]

# %%
df['Total price'] = df['Quantity']*df['UnitPrice']
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country  Total price
# ...

# %%
data2 = df.pivot_table('Total price',index = 'StockCode',aggfunc = 'mean')
data2
# Out:
#               Total price
# StockCode
# 10002           10.409452
# 10080            4.962083
# 10120            1.351000
# 10123C           0.812500
# 10123G           0.000000
# ...                   ...
# gift_0001_20    16.705000
# gift_0001_30    21.941250
# gift_0001_40    33.566667
# gift_0001_50    41.890000
# m                2.550000
#
# [4070 rows x 1 columns]

# %%
data1['Mean_Total Price'] = data2['Total price']
data1
# Out:
#               Quantity  Mean_Total Price
# StockCode
# 10002             1037         10.409452
# 10080              495          4.962083
# 10120              193          1.351000
# 10123C             -13          0.812500
# 10123G             -38          0.000000
# ...                ...               ...
# gift_0001_20        20         16.705000
# gift_0001_30        37         21.941250
# gift_0001_40         3         33.566667
# gift_0001_50         4         41.890000
# m                    1          2.550000
#
# [4070 rows x 2 columns]

# %%
df['Date'] = pd.to_datetime(df['InvoiceDate']).dt.date
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country  Total price  \
# ...

# %%
df.pivot_table('Total price',index = 'Date',columns ='' aggfunc = 'mean')
